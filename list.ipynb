# %% [markdown]
# <a href="https://colab.research.google.com/github/srinath4304/srinath_4304_ds_/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list = [10, 20, 30, 40]
print(my_list)
# Out:
# [10, 20, 30, 40]

# %%
numbers = [1, 2, 3, 4, 5]

print(numbers[0])
print(numbers[-1])
print(numbers[1:4])
# Out:
# 1
# 5
# [2, 3, 4]

# %%
lst = [1, 2, 3]

lst.append(4)
lst.insert(1, 10)
lst.extend([5, 6])
print(lst)
# Out:
# [1, 10, 2, 3, 4, 5, 6]

# %%
lst = [10, 20, 30, 40]

lst.remove(20)
lst.pop()
lst.pop(1)
del lst[0]
print(lst)
# Out:
# []
