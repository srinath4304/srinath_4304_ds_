# %% [markdown]
# <a href="https://colab.research.google.com/github/srinath4304/srinath_4304_ds_/blob/main/WEEK-1/dictionary_operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creating a dictionary
d = {
    "name": "Zaid",
    "age": 19,
    "course": "BE"
    }
print("Original dictionary:", d)
# Out:
# Original dictionary: {'name': 'Zaid', 'age': 19, 'course': 'BE'}

# %%
d = {
    "name": "Zaid",
    "age": 19,
    "course": "BE"
}
# Accessing values
print("Name:", d["name"])
print("Age:", d.get("age"))
# Out:
# Name: Zaid
# Age: 19

# %%
d = {
    "name": "Zaid",
    "age": 19,
    "course": "BE"
}
# Adding a new key-value pair
d["college"] = "XYZ University"
print("After adding:", d)
# Out:
# After adding: {'name': 'Zaid', 'age': 19, 'course': 'BE', 'college': 'XYZ University'}

# %%
d = {
    "name": "Zaid",
    "age": 19,
    "course": "BE"
}
# Updating value
d["age"] = 21
print("After updating:", d)
# Out:
# After updating: {'name': 'Zaid', 'age': 21, 'course': 'BE'}

# %%
d = {
    "name": "Zaid",
    "age": 19,
    "course": "BE"
}
# Removing elements
d.pop("course")
print("After pop:", d)
removed_item = d.popitem()
print("After popitem:", d)
print("Removed item:", removed_item)
# Out:
# After pop: {'name': 'Zaid', 'age': 19}
# After popitem: {'name': 'Zaid'}
# Removed item: ('age', 19)

# %%
d = {
    "name": "Zaid",
    "age": 19,
    "course": "BE"
}
# Keys, values, items
print("Keys:", d.keys())
print("Values:", d.values())
print("Items:", d.items())
# Out:
# Keys: dict_keys(['name', 'age', 'course'])
# Values: dict_values(['Zaid', 19, 'BE'])
# Items: dict_items([('name', 'Zaid'), ('age', 19), ('course', 'BE')])

# %%
d = {
    "name": "Zaid",
    "age": 19,
    "course": "BE"
}
# Length
print("Length of dictionary:", len(d))
# Out:
# Length of dictionary: 3

# %%
d = {
    "name": "Zaid",
    "age": 19,
    "course": "BE"
}
# Looping through dictionary
print("Looping through keys:")
for key in d:
    print(key, ":", d[key])
print("Looping through key-value pairs:")
for k, v in d.items():
    print(k, "->", v)
# Out:
# Looping through keys:
# name : Zaid
# age : 19
# course : BE
# Looping through key-value pairs:
# name -> Zaid
# age -> 19
# course -> BE

# %%
d = {
    "name": "Zaid",
    "age": 19,
    "course": "BE"
}
# Updating using update()
d.update({"city": "Hyderabad", "age": 22})
print("After update():", d)
# Out:
# After update(): {'name': 'Zaid', 'age': 22, 'course': 'BE', 'city': 'Hyderabad'}

# %%
# Nested dictionary
student = {
    "id": 1,
    "info": {
        "name": "Amit",
        "marks": 90
    }
}
print("Nested dictionary value:", student["info"]["marks"])
# Out:
# Nested dictionary value: 90

# %%
d = {
    "name": "Zaid",
    "age": 19,
    "course": "BE"
}
# Clearing dictionary
d.clear()
print("After clear:", d)
# Out:
# After clear: {}
