# %% [markdown]
# <a href="https://colab.research.google.com/github/srinath4304/srinath_4304_ds_/blob/main/WEEK-2/sortingtechniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter number of elements: "))
arr = []
for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))
print("\nOriginal array:", arr)
for i in range(n - 1):
    min_index = i
    for j in range(i + 1, n):
        if arr[j] < arr[min_index]:
            min_index = j3

    arr[i], arr[min_index] = arr[min_index], arr[i]
print("Sorted array:", arr)
# Out:
# Enter number of elements: 1
# Enter element 1: 2
#
# Original array: [2]
# Sorted array: [2]

# %%
n = int(input("Enter number of elements: "))
arr = []
for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))
print("\nOriginal array:", arr)
for i in range(n-1):
  for j in range(n-1-i):
    if arr[j] > arr[j+1]:
      arr[j],arr[j+1]=arr[j+1],arr[j]
print("Sorted array:", arr)
# Out:
# Enter number of elements: 1
# Enter element 1: 2
#
# Original array: [2]
# Sorted array: [2]
